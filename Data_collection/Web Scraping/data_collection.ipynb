# %%
# Web Scraping

import requests

URL = "https://www.scrapethissite.com/pages/simple/"

res = requests.get(URL)

# %%
if res.status_code == 200:
    print(res.headers)
    
with open("scraped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)
# Out:
# {'Date': 'Thu, 25 Dec 2025 06:37:57 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=ezxzrKjmTJoHd%2BA5J6Q0Sujfa411u8xp8u0BNIB7J3w%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1766644677"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=ezxzrKjmTJoHd%2BA5J6Q0Sujfa411u8xp8u0BNIB7J3w%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1766644677"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9b3655303bb6a631-MRS', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
# BeautifulSoup

from bs4 import BeautifulSoup

with open("scraped_data/data1.html", "r", encoding="utf-8") as f:
    html_content = f.read()

Soup = BeautifulSoup(html_content, "lxml")

# %%
# Extract Name And Population.

# Soup.find("h3")
# Soup.h3

all_countries = []

all_h3 = Soup.find_all("h3")

for h3 in all_h3:
    name = h3.get_text(strip=True)
    # print(h3.find_parent("div")["class"])

    population = h3.find_next("div").select("span.country-population")[0].get_text(strip=True)
    print(h3.find_next("div").select_one("span.country-population").get_text(strip=True))

    # print(h3.attrs)

    all_countries.append([name, population])
# Out:
# 84000
# 4975593
# 29121286
# 86754
# 13254
# 2986952
# 2968000
# 13068161
# 0
# 41343201
# 57881
# 8205000
# 21515754
# 71566
# 26711
# 8303512
# 4590000
# 285653
# 156118464
# 10403000
# 16241811
# 7148785
# 738004
# 9863117
# 9056010
# 8450
# 65365
# 395027
# 9947418
# 18012
# 201103330
# 301790
# 699847
# 0
# 2029307
# 9685000
# 314522
# 33679000
# 628
# 70916439
# 4844927
# 3039126
# 7581000
# 21058798
# 21388
# 16746491
# 19294149
# 1330044000
# 47790000
# 4516220
# 11423000
